# %% [raw]
# !pip install javalang

# %%
import os, javalang
from pprint import pprint
                
def parse_java_files_file_level_interface_class(PATH, root_PATH):
    with open("{}_count_interface_class.csv".format(root_PATH), "w") as ff:  ## file for field
        ff.write("{},{},{},{},{}\n".format("file", "num_of_anony", "num_of_interface", "num_of_class", "line_of_code"))
        ## start to iterate the files:
        for file in os.listdir(PATH):
            if ".java" not in file:
                continue
            #####
            ## within each code file:
            #####
            try:
                with open(os.path.join(PATH, file), "r") as pf:
                    content = pf.readlines()
                    code_string = "".join(content)
                    tree = javalang.parse.parse(code_string)
                    #####
                    counter_of_anony = "??"
                    #####
                    counter_interface = 0
                    ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
                    for path, node in tree.filter(javalang.tree.InterfaceDeclaration):
                        counter_interface += 1
                    #####
                    counter_class = 0
                    ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
                    for path, node in tree.filter(javalang.tree.ClassDeclaration):
                        counter_class += 1
                    ff.write("{},{},{},{},{}\n".format(file, counter_of_anony, counter_interface, counter_class,
                                                       len(content)))
            except:
                print("failed:", file)


def parse_java_files_class_level_method(PATH, root_PATH):
    with open("{}_method.csv".format(root_PATH), "w") as ff:  ## file for field
        ff.write(
            "{},{},{},{},{},{},{}\n".format(
                "file",
                "NOM_avg", "NOM_max", "NOM_total",
                "NSM_avg", "NSM_max", "NSM_total"
            )
        )
        ## start to iterate the files:
        for file in os.listdir(PATH):
            if ".java" not in file:
                continue
            #####
            ## within each code file:
            #####
            try:
                with open(os.path.join(PATH, file), "r") as pf:
                    content = pf.readlines()
                code_string = "".join(content)
                tree = javalang.parse.parse(code_string)
                normal = {
                    "max": 0,
                    "avg": 0,
                    "num_of_class": 0,
                    "total": 0
                }
                static = {
                    "max": 0,
                    "avg": 0,
                    "num_of_class": 0,
                    "total": 0
                }
                ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
                for path, node in tree.filter(javalang.tree.ClassDeclaration):
                    #####
                    ## within each class:
                    #####
                    ## methods:
                    normal["num_of_class"] += 1
                    static["num_of_class"] += 1
                    counter_method = 0
                    counter_method_static = 0
                    for path1, node1 in node.filter(
                            javalang.tree.MethodDeclaration):  ## node1 is each line of MethodDeclaration
                        if "static" in node1.modifiers:
                            counter_method_static += 1
                        else:
                            counter_method += 1
                    normal["max"] = normal["max"] if counter_method <= normal["max"] else counter_method
                    static["max"] = static["max"] if counter_method_static <= static["max"] else counter_method_static
                    normal["total"] += counter_method
                    static["total"] += counter_method_static
                normal["avg"] = normal["total"] / normal["num_of_class"] if normal["num_of_class"] > 0 else 1  ### IF THE normal["num_of_class"] IS 0, THEN WE WILL MANUALLY CHANGE IT TO 1
                static["avg"] = static["total"] / static["num_of_class"] if normal["num_of_class"] > 0 else 1  ### IF THE normal["num_of_class"] IS 0, THEN WE WILL MANUALLY CHANGE IT TO 1
                ff.write(
                    "{},{},{},{},{},{},{}\n".format(
                        file,
                        normal["avg"], normal["max"], normal["total"],
                        static["avg"], static["max"], static["total"],
                    )
                )
            except:
                print("failed:", file)
                continue


def parse_java_files_class_level_field(PATH, root_PATH):
    with open("{}_field.csv".format(root_PATH), "w") as ff:  ## file for field
        ff.write(
            "{},{},{},{},{},{},{}\n".format(
                "file",
                "NOF_avg", "NOF_max", "NOF_total",
                "NSF_avg", "NSF_max", "NSF_total"
            )
        )
        ## start to iterate the files:
        for file in os.listdir(PATH):
            if ".java" not in file:
                continue
            #####
            ## within each code file:
            #####
            try:
                with open(os.path.join(PATH, file), "r") as pf:
                    content = pf.readlines()
                code_string = "".join(content)
                tree = javalang.parse.parse(code_string)
                normal = {
                    "max": 0,
                    "avg": 0,
                    "num_of_class": 0,
                    "total": 0
                }
                static = {
                    "max": 0,
                    "avg": 0,
                    "num_of_class": 0,
                    "total": 0
                }
                ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
                for path, node in tree.filter(javalang.tree.ClassDeclaration):
                    #####
                    ## within each class:
                    #####
                    # print(node.name)
                    ## fields:
                    normal["num_of_class"] += 1
                    static["num_of_class"] += 1
                    counter_field = 0
                    counter_field_static = 0
                    for path1, node1 in node.filter(
                            javalang.tree.FieldDeclaration):  ## node1 is each line of FieldDeclaration
                        if "static" in node1.modifiers:
                            for variable_declarator in node1.declarators:  ## basically one declarator is just one line. Within 1 line, there can be several varaibles.
                                # print("static: ", node1.modifiers, variable_declarator.name)
                                counter_field_static += 1
                        else:
                            for variable_declarator in node1.declarators:  ## basically one declarator is just one line. Within 1 line, there can be several varaibles.
                                # print("not: ", node1.modifiers, variable_declarator.name)
                                counter_field += 1
                    normal["max"] = normal["max"] if counter_field <= normal["max"] else counter_field
                    static["max"] = static["max"] if counter_field_static <= static["max"] else counter_field_static
                    normal["total"] += counter_field
                    static["total"] += counter_field_static
                normal["avg"] = normal["total"] / normal["num_of_class"] if normal["num_of_class"] > 0 else 1  ### IF THE normal["num_of_class"] IS 0, THEN WE WILL MANUALLY CHANGE IT TO 1
                static["avg"] = static["total"] / static["num_of_class"] if normal["num_of_class"] > 0 else 1  ### IF THE normal["num_of_class"] IS 0, THEN WE WILL MANUALLY CHANGE IT TO 1
                ff.write(
                    "{},{},{},{},{},{},{}\n".format(
                        file,
                        normal["avg"], normal["max"], normal["total"],
                        static["avg"], static["max"], static["total"],
                    )
                )
            except:
                print("failed:", file)

# %% [markdown]
# ### platform

# %%
parse_java_files_class_level_field("Code/org.eclipse.platform_renamed", "org.eclipse.platform")
parse_java_files_class_level_method("Code/org.eclipse.platform_renamed", "org.eclipse.platform")

parse_java_files_file_level_interface_class("Code/org.eclipse.platform_renamed", "org.eclipse.platform")

# %% [markdown]
# ### jdt.core

# %%
parse_java_files_class_level_field("Code/org.eclipse.jdt.core_renamed", "org.eclipse.jdt.core")
parse_java_files_class_level_method("Code/org.eclipse.jdt.core_renamed", "org.eclipse.jdt.core")

parse_java_files_file_level_interface_class("Code/org.eclipse.jdt.core_renamed", "org.eclipse.jdt.core")
# Out:
# failed: org.eclipse.jdt.core.dom.IBinding.java
# failed: org.eclipse.jdt.core.dom.IMethodBinding.java
# failed: org.eclipse.jdt.core.dom.IPackageBinding.java
# failed: org.eclipse.jdt.core.dom.ITypeBinding.java
# failed: org.eclipse.jdt.core.dom.IVariableBinding.java
# failed: org.eclipse.jdt.core.eval.ICodeSnippetRequestor.java
# failed: org.eclipse.jdt.core.eval.IEvaluationContext.java
# failed: org.eclipse.jdt.core.eval.IGlobalVariable.java
# failed: org.eclipse.jdt.core.IBuffer.java
# failed: org.eclipse.jdt.core.IBufferChangedListener.java
# failed: org.eclipse.jdt.core.IBufferFactory.java
# failed: org.eclipse.jdt.core.IClassFile.java
# failed: org.eclipse.jdt.core.IClasspathContainer.java
# failed: org.eclipse.jdt.core.IClasspathEntry.java
# failed: org.eclipse.jdt.core.ICodeAssist.java
# failed: org.eclipse.jdt.core.ICodeCompletionRequestor.java
# failed: org.eclipse.jdt.core.ICodeFormatter.java
# failed: org.eclipse.jdt.core.ICompilationUnit.java
# failed: org.eclipse.jdt.core.ICompletionRequestor.java
# failed: org.eclipse.jdt.core.ICorrectionRequestor.java
# failed: org.eclipse.jdt.core.IElementChangedListener.java
# failed: org.eclipse.jdt.core.IField.java
# failed: org.eclipse.jdt.core.IImportContainer.java
# failed: org.eclipse.jdt.core.IImportDeclaration.java
# failed: org.eclipse.jdt.core.IInitializer.java
# failed: org.eclipse.jdt.core.IJavaElement.java
# failed: org.eclipse.jdt.core.IJavaElementDelta.java
# failed: org.eclipse.jdt.core.IJavaModel.java
# failed: org.eclipse.jdt.core.IJavaModelMarker.java
# failed: org.eclipse.jdt.core.IJavaModelStatus.java
# failed: org.eclipse.jdt.core.IJavaModelStatusConstants.java
# failed: org.eclipse.jdt.core.IJavaProject.java
# failed: org.eclipse.jdt.core.IMember.java
# failed: org.eclipse.jdt.core.IMethod.java
# failed: org.eclipse.jdt.core.IOpenable.java
# failed: org.eclipse.jdt.core.IPackageDeclaration.java
# failed: org.eclipse.jdt.core.IPackageFragment.java
# failed: org.eclipse.jdt.core.IPackageFragmentRoot.java
# failed: org.eclipse.jdt.core.IParent.java
# failed: org.eclipse.jdt.core.IProblemRequestor.java
# failed: org.eclipse.jdt.core.IRegion.java
# failed: org.eclipse.jdt.core.ISourceManipulation.java
# failed: org.eclipse.jdt.core.ISourceRange.java
# failed: org.eclipse.jdt.core.ISourceReference.java
# failed: org.eclipse.jdt.core.IType.java
# failed: org.eclipse.jdt.core.ITypeHierarchy.java
# failed: org.eclipse.jdt.core.ITypeHierarchyChangedListener.java
# failed: org.eclipse.jdt.core.IWorkingCopy.java
# failed: org.eclipse.jdt.core.jdom.IDOMCompilationUnit.java
# failed: org.eclipse.jdt.core.jdom.IDOMFactory.java
# failed: org.eclipse.jdt.core.jdom.IDOMField.java
# failed: org.eclipse.jdt.core.jdom.IDOMImport.java
# failed: org.eclipse.jdt.core.jdom.IDOMInitializer.java
# failed: org.eclipse.jdt.core.jdom.IDOMMember.java
# failed: org.eclipse.jdt.core.jdom.IDOMMethod.java
# failed: org.eclipse.jdt.core.jdom.IDOMNode.java
# failed: org.eclipse.jdt.core.jdom.IDOMPackage.java
# failed: org.eclipse.jdt.core.jdom.IDOMType.java
# failed: org.eclipse.jdt.core.search.IJavaSearchConstants.java
# failed: org.eclipse.jdt.core.search.IJavaSearchResultCollector.java
# failed: org.eclipse.jdt.core.search.IJavaSearchScope.java
# failed: org.eclipse.jdt.core.search.ISearchPattern.java
# failed: org.eclipse.jdt.core.search.ITypeNameRequestor.java
# failed: org.eclipse.jdt.core.util.IAttributeNamesConstants.java
# failed: org.eclipse.jdt.core.util.IBytecodeVisitor.java
# failed: org.eclipse.jdt.core.util.IClassFileAttribute.java
# failed: org.eclipse.jdt.core.util.IClassFileDisassembler.java
# failed: org.eclipse.jdt.core.util.IClassFileReader.java
# failed: org.eclipse.jdt.core.util.ICodeAttribute.java
# failed: org.eclipse.jdt.core.util.IConstantPool.java
# failed: org.eclipse.jdt.core.util.IConstantPoolConstant.java
# failed: org.eclipse.jdt.core.util.IConstantPoolEntry.java
# failed: org.eclipse.jdt.core.util.IConstantValueAttribute.java
# failed: org.eclipse.jdt.core.util.IExceptionAttribute.java
# failed: org.eclipse.jdt.core.util.IExceptionTableEntry.java
# failed: org.eclipse.jdt.core.util.IFieldInfo.java
# failed: org.eclipse.jdt.core.util.IInnerClassesAttribute.java
# failed: org.eclipse.jdt.core.util.IInnerClassesAttributeEntry.java
# failed: org.eclipse.jdt.core.util.ILineNumberAttribute.java
# failed: org.eclipse.jdt.core.util.ILocalVariableAttribute.java
# failed: org.eclipse.jdt.core.util.ILocalVariableTableEntry.java
# failed: org.eclipse.jdt.core.util.IMethodInfo.java
# failed: org.eclipse.jdt.core.util.IModifierConstants.java
# failed: org.eclipse.jdt.core.util.IOpcodeMnemonics.java
# failed: org.eclipse.jdt.core.util.ISourceAttribute.java
# failed: org.eclipse.jdt.internal.codeassist.ISearchableNameEnvironment.java
# failed: org.eclipse.jdt.internal.codeassist.ISearchRequestor.java
# failed: org.eclipse.jdt.internal.codeassist.ISelectionRequestor.java
# failed: org.eclipse.jdt.internal.codeassist.RelevanceConstants.java
# failed: org.eclipse.jdt.internal.compiler.ast.OperatorIds.java
# failed: org.eclipse.jdt.internal.compiler.classfmt.ClassFileConstants.java
# failed: org.eclipse.jdt.internal.compiler.codegen.AttributeNamesConstants.java
# failed: org.eclipse.jdt.internal.compiler.codegen.Opcodes.java
# failed: org.eclipse.jdt.internal.compiler.codegen.QualifiedNamesConstants.java
# failed: org.eclipse.jdt.internal.compiler.CompilationResult.java
# failed: org.eclipse.jdt.internal.compiler.env.IBinaryField.java
# failed: org.eclipse.jdt.internal.compiler.env.IBinaryMethod.java
# failed: org.eclipse.jdt.internal.compiler.env.IBinaryNestedType.java
# failed: org.eclipse.jdt.internal.compiler.env.IBinaryType.java
# failed: org.eclipse.jdt.internal.compiler.env.ICompilationUnit.java
# failed: org.eclipse.jdt.internal.compiler.env.IConstants.java
# failed: org.eclipse.jdt.internal.compiler.env.IDependent.java
# failed: org.eclipse.jdt.internal.compiler.env.IGenericField.java
# failed: org.eclipse.jdt.internal.compiler.env.IGenericMethod.java
# failed: org.eclipse.jdt.internal.compiler.env.IGenericType.java
# failed: org.eclipse.jdt.internal.compiler.env.INameEnvironment.java
# failed: org.eclipse.jdt.internal.compiler.env.ISourceField.java
# failed: org.eclipse.jdt.internal.compiler.env.ISourceMethod.java
# failed: org.eclipse.jdt.internal.compiler.env.ISourceType.java
# failed: org.eclipse.jdt.internal.compiler.IAbstractSyntaxTreeVisitor.java
# failed: org.eclipse.jdt.internal.compiler.ICompilerRequestor.java
# failed: org.eclipse.jdt.internal.compiler.IDebugRequestor.java
# failed: org.eclipse.jdt.internal.compiler.IDocumentElementRequestor.java
# failed: org.eclipse.jdt.internal.compiler.IErrorHandlingPolicy.java
# failed: org.eclipse.jdt.internal.compiler.impl.ITypeRequestor.java
# failed: org.eclipse.jdt.internal.compiler.impl.ReferenceContext.java
# failed: org.eclipse.jdt.internal.compiler.IProblemFactory.java
# failed: org.eclipse.jdt.internal.compiler.ISourceElementRequestor.java
# failed: org.eclipse.jdt.internal.compiler.lookup.BaseTypes.java
# failed: org.eclipse.jdt.internal.compiler.lookup.BindingIds.java
# failed: org.eclipse.jdt.internal.compiler.lookup.CompilerModifiers.java
# failed: org.eclipse.jdt.internal.compiler.lookup.InvocationSite.java
# failed: org.eclipse.jdt.internal.compiler.lookup.ProblemReasons.java
# failed: org.eclipse.jdt.internal.compiler.lookup.SourceTypeBinding.java
# failed: org.eclipse.jdt.internal.compiler.lookup.TagBits.java
# failed: org.eclipse.jdt.internal.compiler.lookup.TypeConstants.java
# failed: org.eclipse.jdt.internal.compiler.lookup.TypeIds.java
# failed: org.eclipse.jdt.internal.compiler.parser.ParserBasicInformation.java
# failed: org.eclipse.jdt.internal.compiler.problem.ProblemSeverities.java
# failed: org.eclipse.jdt.internal.core.CopyResourceElementsOperation.java
# failed: org.eclipse.jdt.internal.core.hierarchy.IHierarchyRequestor.java
# failed: org.eclipse.jdt.internal.core.IJavaElementRequestor.java
# failed: org.eclipse.jdt.internal.core.index.IDocument.java
# failed: org.eclipse.jdt.internal.core.index.IEntryResult.java
# failed: org.eclipse.jdt.internal.core.index.IIndex.java
# failed: org.eclipse.jdt.internal.core.index.IIndexer.java
# failed: org.eclipse.jdt.internal.core.index.IIndexerOutput.java
# failed: org.eclipse.jdt.internal.core.index.impl.ICacheEnumeration.java
# failed: org.eclipse.jdt.internal.core.index.impl.IIndexConstants.java
# failed: org.eclipse.jdt.internal.core.index.impl.ILRUCacheable.java
# failed: org.eclipse.jdt.internal.core.index.IQueryResult.java
# failed: org.eclipse.jdt.internal.core.IPathRequestor.java
# failed: org.eclipse.jdt.internal.core.jdom.ILineStartFinder.java
# failed: org.eclipse.jdt.internal.core.search.IIndexSearchRequestor.java
# failed: org.eclipse.jdt.internal.core.search.IInfoConstants.java
# failed: org.eclipse.jdt.internal.core.search.indexing.IIndexConstants.java
# failed: org.eclipse.jdt.internal.core.search.processing.IJob.java
# failed: org.eclipse.jdt.internal.core.util.ICacheEnumeration.java
# failed: org.eclipse.jdt.internal.core.util.IDumpable.java
# failed: org.eclipse.jdt.internal.core.util.ILRUCacheable.java
# failed: org.eclipse.jdt.internal.eval.EvaluationConstants.java
# failed: org.eclipse.jdt.internal.eval.IRequestor.java
# failed: org.eclipse.jdt.core.dom.IBinding.java
# failed: org.eclipse.jdt.core.dom.IMethodBinding.java
# failed: org.eclipse.jdt.core.dom.IPackageBinding.java
# failed: org.eclipse.jdt.core.dom.ITypeBinding.java
# failed: org.eclipse.jdt.core.dom.IVariableBinding.java
# failed: org.eclipse.jdt.core.eval.ICodeSnippetRequestor.java
# failed: org.eclipse.jdt.core.eval.IEvaluationContext.java
# failed: org.eclipse.jdt.core.eval.IGlobalVariable.java
# failed: org.eclipse.jdt.core.IBuffer.java
# failed: org.eclipse.jdt.core.IBufferChangedListener.java
# failed: org.eclipse.jdt.core.IBufferFactory.java
# failed: org.eclipse.jdt.core.IClassFile.java
# failed: org.eclipse.jdt.core.IClasspathContainer.java
# failed: org.eclipse.jdt.core.IClasspathEntry.java
# failed: org.eclipse.jdt.core.ICodeAssist.java
# failed: org.eclipse.jdt.core.ICodeCompletionRequestor.java
# failed: org.eclipse.jdt.core.ICodeFormatter.java
# failed: org.eclipse.jdt.core.ICompilationUnit.java
# failed: org.eclipse.jdt.core.ICompletionRequestor.java
# failed: org.eclipse.jdt.core.ICorrectionRequestor.java
# failed: org.eclipse.jdt.core.IElementChangedListener.java
# failed: org.eclipse.jdt.core.IField.java
# failed: org.eclipse.jdt.core.IImportContainer.java
# failed: org.eclipse.jdt.core.IImportDeclaration.java
# failed: org.eclipse.jdt.core.IInitializer.java
# failed: org.eclipse.jdt.core.IJavaElement.java
# failed: org.eclipse.jdt.core.IJavaElementDelta.java
# failed: org.eclipse.jdt.core.IJavaModel.java
# failed: org.eclipse.jdt.core.IJavaModelMarker.java
# failed: org.eclipse.jdt.core.IJavaModelStatus.java
# failed: org.eclipse.jdt.core.IJavaModelStatusConstants.java
# failed: org.eclipse.jdt.core.IJavaProject.java
# failed: org.eclipse.jdt.core.IMember.java
# failed: org.eclipse.jdt.core.IMethod.java
# failed: org.eclipse.jdt.core.IOpenable.java
# failed: org.eclipse.jdt.core.IPackageDeclaration.java
# failed: org.eclipse.jdt.core.IPackageFragment.java
# failed: org.eclipse.jdt.core.IPackageFragmentRoot.java
# failed: org.eclipse.jdt.core.IParent.java
# failed: org.eclipse.jdt.core.IProblemRequestor.java
# failed: org.eclipse.jdt.core.IRegion.java
# failed: org.eclipse.jdt.core.ISourceManipulation.java
# failed: org.eclipse.jdt.core.ISourceRange.java
# failed: org.eclipse.jdt.core.ISourceReference.java
# failed: org.eclipse.jdt.core.IType.java
# failed: org.eclipse.jdt.core.ITypeHierarchy.java
# failed: org.eclipse.jdt.core.ITypeHierarchyChangedListener.java
# failed: org.eclipse.jdt.core.IWorkingCopy.java
# failed: org.eclipse.jdt.core.jdom.IDOMCompilationUnit.java
# failed: org.eclipse.jdt.core.jdom.IDOMFactory.java
# failed: org.eclipse.jdt.core.jdom.IDOMField.java
# failed: org.eclipse.jdt.core.jdom.IDOMImport.java
# failed: org.eclipse.jdt.core.jdom.IDOMInitializer.java
# failed: org.eclipse.jdt.core.jdom.IDOMMember.java
# failed: org.eclipse.jdt.core.jdom.IDOMMethod.java
# failed: org.eclipse.jdt.core.jdom.IDOMNode.java
# failed: org.eclipse.jdt.core.jdom.IDOMPackage.java
# failed: org.eclipse.jdt.core.jdom.IDOMType.java
# failed: org.eclipse.jdt.core.search.IJavaSearchConstants.java
# failed: org.eclipse.jdt.core.search.IJavaSearchResultCollector.java
# failed: org.eclipse.jdt.core.search.IJavaSearchScope.java
# failed: org.eclipse.jdt.core.search.ISearchPattern.java
# failed: org.eclipse.jdt.core.search.ITypeNameRequestor.java
# failed: org.eclipse.jdt.core.util.IAttributeNamesConstants.java
# failed: org.eclipse.jdt.core.util.IBytecodeVisitor.java
# failed: org.eclipse.jdt.core.util.IClassFileAttribute.java
# failed: org.eclipse.jdt.core.util.IClassFileDisassembler.java
# failed: org.eclipse.jdt.core.util.IClassFileReader.java
# failed: org.eclipse.jdt.core.util.ICodeAttribute.java
# failed: org.eclipse.jdt.core.util.IConstantPool.java
# failed: org.eclipse.jdt.core.util.IConstantPoolConstant.java
# failed: org.eclipse.jdt.core.util.IConstantPoolEntry.java
# failed: org.eclipse.jdt.core.util.IConstantValueAttribute.java
# failed: org.eclipse.jdt.core.util.IExceptionAttribute.java
# failed: org.eclipse.jdt.core.util.IExceptionTableEntry.java
# failed: org.eclipse.jdt.core.util.IFieldInfo.java
# failed: org.eclipse.jdt.core.util.IInnerClassesAttribute.java
# failed: org.eclipse.jdt.core.util.IInnerClassesAttributeEntry.java
# failed: org.eclipse.jdt.core.util.ILineNumberAttribute.java
# failed: org.eclipse.jdt.core.util.ILocalVariableAttribute.java
# failed: org.eclipse.jdt.core.util.ILocalVariableTableEntry.java
# failed: org.eclipse.jdt.core.util.IMethodInfo.java
# failed: org.eclipse.jdt.core.util.IModifierConstants.java
# failed: org.eclipse.jdt.core.util.IOpcodeMnemonics.java
# failed: org.eclipse.jdt.core.util.ISourceAttribute.java
# failed: org.eclipse.jdt.internal.codeassist.ISearchableNameEnvironment.java
# failed: org.eclipse.jdt.internal.codeassist.ISearchRequestor.java
# failed: org.eclipse.jdt.internal.codeassist.ISelectionRequestor.java
# failed: org.eclipse.jdt.internal.codeassist.RelevanceConstants.java
# failed: org.eclipse.jdt.internal.compiler.ast.OperatorIds.java
# failed: org.eclipse.jdt.internal.compiler.classfmt.ClassFileConstants.java
# failed: org.eclipse.jdt.internal.compiler.codegen.AttributeNamesConstants.java
# failed: org.eclipse.jdt.internal.compiler.codegen.Opcodes.java
# failed: org.eclipse.jdt.internal.compiler.codegen.QualifiedNamesConstants.java
# failed: org.eclipse.jdt.internal.compiler.CompilationResult.java
# failed: org.eclipse.jdt.internal.compiler.env.IBinaryField.java
# failed: org.eclipse.jdt.internal.compiler.env.IBinaryMethod.java
# failed: org.eclipse.jdt.internal.compiler.env.IBinaryNestedType.java
# failed: org.eclipse.jdt.internal.compiler.env.IBinaryType.java
# failed: org.eclipse.jdt.internal.compiler.env.ICompilationUnit.java
# failed: org.eclipse.jdt.internal.compiler.env.IConstants.java
# failed: org.eclipse.jdt.internal.compiler.env.IDependent.java
# failed: org.eclipse.jdt.internal.compiler.env.IGenericField.java
# failed: org.eclipse.jdt.internal.compiler.env.IGenericMethod.java
# failed: org.eclipse.jdt.internal.compiler.env.IGenericType.java
# failed: org.eclipse.jdt.internal.compiler.env.INameEnvironment.java
# failed: org.eclipse.jdt.internal.compiler.env.ISourceField.java
# failed: org.eclipse.jdt.internal.compiler.env.ISourceMethod.java
# failed: org.eclipse.jdt.internal.compiler.env.ISourceType.java
# failed: org.eclipse.jdt.internal.compiler.IAbstractSyntaxTreeVisitor.java
# failed: org.eclipse.jdt.internal.compiler.ICompilerRequestor.java
# failed: org.eclipse.jdt.internal.compiler.IDebugRequestor.java
# failed: org.eclipse.jdt.internal.compiler.IDocumentElementRequestor.java
# failed: org.eclipse.jdt.internal.compiler.IErrorHandlingPolicy.java
# failed: org.eclipse.jdt.internal.compiler.impl.ITypeRequestor.java
# failed: org.eclipse.jdt.internal.compiler.impl.ReferenceContext.java
# failed: org.eclipse.jdt.internal.compiler.IProblemFactory.java
# failed: org.eclipse.jdt.internal.compiler.ISourceElementRequestor.java
# failed: org.eclipse.jdt.internal.compiler.lookup.BaseTypes.java
# failed: org.eclipse.jdt.internal.compiler.lookup.BindingIds.java
# failed: org.eclipse.jdt.internal.compiler.lookup.CompilerModifiers.java
# failed: org.eclipse.jdt.internal.compiler.lookup.InvocationSite.java
# failed: org.eclipse.jdt.internal.compiler.lookup.ProblemReasons.java
# failed: org.eclipse.jdt.internal.compiler.lookup.SourceTypeBinding.java
# failed: org.eclipse.jdt.internal.compiler.lookup.TagBits.java
# failed: org.eclipse.jdt.internal.compiler.lookup.TypeConstants.java
# failed: org.eclipse.jdt.internal.compiler.lookup.TypeIds.java
# failed: org.eclipse.jdt.internal.compiler.parser.ParserBasicInformation.java
# failed: org.eclipse.jdt.internal.compiler.problem.ProblemSeverities.java
# failed: org.eclipse.jdt.internal.core.CopyResourceElementsOperation.java
# failed: org.eclipse.jdt.internal.core.hierarchy.IHierarchyRequestor.java
# failed: org.eclipse.jdt.internal.core.IJavaElementRequestor.java
# failed: org.eclipse.jdt.internal.core.index.IDocument.java
# failed: org.eclipse.jdt.internal.core.index.IEntryResult.java
# failed: org.eclipse.jdt.internal.core.index.IIndex.java
# failed: org.eclipse.jdt.internal.core.index.IIndexer.java
# failed: org.eclipse.jdt.internal.core.index.IIndexerOutput.java
# failed: org.eclipse.jdt.internal.core.index.impl.ICacheEnumeration.java
# failed: org.eclipse.jdt.internal.core.index.impl.IIndexConstants.java
# failed: org.eclipse.jdt.internal.core.index.impl.ILRUCacheable.java
# failed: org.eclipse.jdt.internal.core.index.IQueryResult.java
# failed: org.eclipse.jdt.internal.core.IPathRequestor.java
# failed: org.eclipse.jdt.internal.core.jdom.ILineStartFinder.java
# failed: org.eclipse.jdt.internal.core.search.IIndexSearchRequestor.java
# failed: org.eclipse.jdt.internal.core.search.IInfoConstants.java
# failed: org.eclipse.jdt.internal.core.search.indexing.IIndexConstants.java
# failed: org.eclipse.jdt.internal.core.search.processing.IJob.java
# failed: org.eclipse.jdt.internal.core.util.ICacheEnumeration.java
# failed: org.eclipse.jdt.internal.core.util.IDumpable.java
# failed: org.eclipse.jdt.internal.core.util.ILRUCacheable.java
# failed: org.eclipse.jdt.internal.eval.EvaluationConstants.java
# failed: org.eclipse.jdt.internal.eval.IRequestor.java
# failed: org.eclipse.jdt.internal.compiler.CompilationResult.java
# failed: org.eclipse.jdt.internal.compiler.lookup.SourceTypeBinding.java
# failed: org.eclipse.jdt.internal.core.CopyResourceElementsOperation.java

# %%
# for file in os.listdir(PATH):
#         if ".java" not in file:
#             continue
#         #####
#         ## within each code file: 
#         #####
#         with open(os.path.join(PATH, file), "r") as pf:
#             content = pf.readlines()
#             code_string = "".join(content)
#             tree = javalang.parse.parse(code_string)
#             ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
#             for path, node in tree.filter(javalang.tree.ClassDeclaration):
#                 #####
#                 ## within each class: 
#                 #####
#                 # print(node.name)
#                 ## fields: 
#                 with open("{}.csv".format(root_PATH), "w") as ff: ## file for field
#                     ff.write("{},{},{},{}\n".format("file", "class", "num_of_field", "num_of_static_field"))
#                 counter_field = 0
#                 counter_field_static = 0
#                 for path1, node1 in node.filter(javalang.tree.FieldDeclaration): ## node1 is each line of FieldDeclaration
#                     if "static" in node1.modifiers:
#                         for variable_declarator in node1.declarators: ## basically one declarator is just one line. Within 1 line, there can be several varaibles. 
#                             # print("static: ", node1.modifiers, variable_declarator.name)
#                             counter_field_static += 1
#                     else:
#                         for variable_declarator in node1.declarators: ## basically one declarator is just one line. Within 1 line, there can be several varaibles. 
#                             # print("not: ", node1.modifiers, variable_declarator.name)
#                             counter_field += 1
#                 # print(file, node.name, counter_field, counter_field_static, "\n")
#                 ## methods:
#                 counter_method = 0
#                 counter_method_static = 0
#                 for path1, node1 in node.filter(javalang.tree.MethodDeclaration): ## node1 is each line of MethodDeclaration
#                     if "static" in node1.modifiers: 
#                         counter_method_static += 1
#                     else:
#                         counter_method += 1
#                 # print(file, node.name, counter_method, counter_method_static, "\n")
#             break
