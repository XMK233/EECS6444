# %% [markdown]
# ## Extract the java code for .java,v files.
# * We cannot get enough .java,v files from `jdt`, `platform`. We have to look at `jdt.core`.
# * How do we find a counterpart of `jdt.core` for `platform`?

# %%
# -*- coding: utf-8 -*-
import os, re
import pandas as pd

# PATH_JDT = r"J:\EECS6444\Raw_Data\cvs_target\org.eclipse.jdt"
PATH_PLATFORM = r"J:\EECS6444\Raw_Data\cvs_target\org.eclipse.platform"
PATH_JDT_CORE = r"J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core"

def parse_file(PATH, root_PATH, path, file, encoding_method):
    if ".java,v" not in file:
        return
    ## get the lines from original files. 
    lines = None
    with open(os.path.join(path, file), "r", encoding=encoding_method, errors="ignore") as f: # , encoding="utf-8" 
        lines = f.readlines()
    ## skip the non-java file
    ## this is the latest version of this file. 
    # print(re.split("\s", lines[0].replace(";", ""))[1])
    log_start = False
    full_code = []
    ##
    for l in lines:
        line = l.strip() #.lower()
        if log_start:
            full_code.append(line)
        ## log starts from here.
        if line == "text":
            log_start = True
        ## log ends here.
        if line == "@" and log_start == True:
            break
    code_content = "\n".join(full_code)[1:-1]
    ##
    file_name = root_PATH + os.path.join(path, file).replace(PATH, "").replace(",v", "").replace(os.sep, "-")
    with open(os.path.join(root_PATH, file_name), "w") as rf:
        rf.write(code_content)
    return

def read_through_all_the_files_in_a_path(PATH):
    root_PATH = PATH.split("\\")[-1]
    ## java files will be stored into this folder. 
    if not os.path.exists(root_PATH):
        os.makedirs(root_PATH)
    group = os.walk(PATH)
    for path, directory, filelist in group:
        for file in filelist:
            try:
                parse_file(PATH, root_PATH, path, file, "utf-8")
            except: 
                print("failed with utf-8: {}\n".format(os.path.join(path, file)))
#                 try: 
#                     parse_file(PATH, root_PATH, path, file, "gbk")
#                 except:
#                     print("failed with gbk: {}\n".format(os.path.join(path, file)))
#                     try: 
#                         parse_file(PATH, root_PATH, path, file, "gb18030")
#                     except:
#                         print("failed with gb18030: {}\n\n-----------------\n\n".format(os.path.join(path, file)))
    return

read_through_all_the_files_in_a_path(PATH_PLATFORM) 
# read_through_all_the_files_in_a_path(PATH_JDT_CORE)

# %%
import os, re
def rename_java_files(root_PATH, new_root_PATH):
    """
    Rename the file as this format: package.name.java. 
    Kim insist so. I don't know the meaning of naming like this. 
    """
    if not os.path.exists(new_root_PATH):
        os.makedirs(new_root_PATH)
    for code_file in os.listdir(root_PATH):
        with open(os.path.join(os.getcwd(), root_PATH, code_file), "r") as cf:
            lines = cf.readlines()
        for line in lines:
            if "package " not in line:
                continue
            match_rst = re.match("^package [\s\S]+;$", line)
            if match_rst == None:
                continue
            ### 
            package_name = match_rst.group().split()[1][0:-1]
            java_file_name = code_file.split("-")[-1]
            with open(os.path.join(os.getcwd(), new_root_PATH, "{}.{}".format(package_name, java_file_name)  ), "w") as ff:
                ff.write("".join(lines))
            break
rename_java_files("org.eclipse.jdt.core", "org.eclipse.jdt.core_renamed")
# rename_java_files("org.eclipse.platform", "org.eclipse.platform_renamed")

# %% [markdown]
# ## Failed files:
#
# ### How to deal with it? When reading file, use param: ignore = True
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\CharOperation.java,v
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\InvalidInputException.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\InvalidInputException.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\InvalidInputException.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\IProblem.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\IProblem.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\IProblem.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\Attic\IScanner.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\Attic\IScanner.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\Attic\IScanner.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\Attic\ITerminalSymbols.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\Attic\ITerminalSymbols.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\core\compiler\Attic\ITerminalSymbols.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\internal\compiler\flow\UnconditionalFlowInfo.java,v
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\internal\compiler\lookup\MethodVerifier15.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\internal\compiler\lookup\MethodVerifier15.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\internal\compiler\lookup\MethodVerifier15.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\internal\compiler\parser\TerminalTokens.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\internal\compiler\parser\TerminalTokens.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\compiler\org\eclipse\jdt\internal\compiler\parser\TerminalTokens.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\dom\org\eclipse\jdt\core\dom\SimpleName.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\dom\org\eclipse\jdt\core\dom\SimpleName.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\dom\org\eclipse\jdt\core\dom\SimpleName.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IClasspathEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IClasspathEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IClasspathEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeAssist.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeAssist.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeAssist.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeCompletionRequestor.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeCompletionRequestor.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeCompletionRequestor.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeFormatter.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeFormatter.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICodeFormatter.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICompilationUnit.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICompilationUnit.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICompilationUnit.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICompletionRequestor.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICompletionRequestor.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICompletionRequestor.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICorrectionRequestor.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICorrectionRequestor.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ICorrectionRequestor.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IElementChangedListener.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IElementChangedListener.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IElementChangedListener.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IField.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IField.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IField.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IImportContainer.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IImportContainer.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IImportContainer.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IImportDeclaration.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IImportDeclaration.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IImportDeclaration.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IInitializer.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IInitializer.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IInitializer.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaElement.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaElement.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaElement.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaElementDelta.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaElementDelta.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaElementDelta.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModel.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModel.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModel.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelMarker.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelMarker.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelMarker.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelStatus.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelStatus.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelStatus.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelStatusConstants.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelStatusConstants.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaModelStatusConstants.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaProject.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaProject.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IJavaProject.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IMember.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IMember.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IMember.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IMethod.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IMethod.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IMethod.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IOpenable.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IOpenable.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IOpenable.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IPackageDeclaration.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IPackageDeclaration.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IPackageDeclaration.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IProblemRequestor.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IProblemRequestor.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IProblemRequestor.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IWorkingCopy.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IWorkingCopy.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\IWorkingCopy.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ToolFactory.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ToolFactory.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\ToolFactory.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\compiler\IScanner.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\compiler\IScanner.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\compiler\IScanner.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\compiler\ITerminalSymbols.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\compiler\ITerminalSymbols.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\compiler\ITerminalSymbols.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ByteCodeVisitorAdapter.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ByteCodeVisitorAdapter.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ByteCodeVisitorAdapter.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ClassFormatException.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ClassFormatException.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ClassFormatException.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IAttributeNamesConstants.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IAttributeNamesConstants.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IAttributeNamesConstants.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IBytecodeVisitor.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IBytecodeVisitor.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IBytecodeVisitor.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileDisassembler.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileDisassembler.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileDisassembler.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileReader.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileReader.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IClassFileReader.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ICodeAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ICodeAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ICodeAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPool.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPool.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPool.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPoolConstant.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPoolConstant.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPoolConstant.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPoolEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPoolEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantPoolEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantValueAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantValueAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IConstantValueAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IExceptionAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IExceptionAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IExceptionAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IExceptionTableEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IExceptionTableEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IExceptionTableEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IFieldInfo.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IFieldInfo.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IFieldInfo.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IInnerClassesAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IInnerClassesAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IInnerClassesAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IInnerClassesAttributeEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IInnerClassesAttributeEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IInnerClassesAttributeEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILineNumberAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILineNumberAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILineNumberAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILocalVariableAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILocalVariableAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILocalVariableAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILocalVariableTableEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILocalVariableTableEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ILocalVariableTableEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IMethodInfo.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IMethodInfo.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IMethodInfo.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IModifierConstants.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IModifierConstants.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IModifierConstants.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IOpcodeMnemonics.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IOpcodeMnemonics.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\IOpcodeMnemonics.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ISourceAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ISourceAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\ISourceAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\OpcodeStringValues.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\OpcodeStringValues.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\OpcodeStringValues.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\DecodingFlag.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\DecodingFlag.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\DecodingFlag.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\JavaModelUtil.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\JavaModelUtil.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\JavaModelUtil.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\Util.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\Util.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\core\util\Attic\Util.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\CompilationUnitProblemFinder.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\CompilationUnitProblemFinder.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\CompilationUnitProblemFinder.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\JavaModelCache.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\JavaModelCache.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\JavaModelCache.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\CharArrayBuffer.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\CharArrayBuffer.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\CharArrayBuffer.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileReader.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileReader.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileReader.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileStruct.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileStruct.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ClassFileStruct.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\CodeAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\CodeAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\CodeAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantPool.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantPool.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantPool.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantPoolEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantPoolEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantPoolEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantValueAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantValueAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ConstantValueAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\DefaultBytecodeVisitor.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\DefaultBytecodeVisitor.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\DefaultBytecodeVisitor.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Disassembler.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Disassembler.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Disassembler.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ExceptionAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ExceptionAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ExceptionAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ExceptionTableEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ExceptionTableEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ExceptionTableEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\FieldInfo.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\FieldInfo.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\FieldInfo.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ICacheEnumeration.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ICacheEnumeration.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ICacheEnumeration.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ILRUCacheable.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ILRUCacheable.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ILRUCacheable.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\InnerClassesAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\InnerClassesAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\InnerClassesAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\InnerClassesAttributeEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\InnerClassesAttributeEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\InnerClassesAttributeEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LineNumberAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LineNumberAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LineNumberAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LocalVariableAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LocalVariableAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LocalVariableAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LocalVariableTableEntry.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LocalVariableTableEntry.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LocalVariableTableEntry.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LRUCache.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LRUCache.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\LRUCache.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\MethodInfo.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\MethodInfo.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\MethodInfo.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ReferenceInfoAdapter.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ReferenceInfoAdapter.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ReferenceInfoAdapter.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\SourceFileAttribute.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\SourceFileAttribute.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\SourceFileAttribute.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ToStringSorter.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ToStringSorter.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\ToStringSorter.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Util.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Util.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Util.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\AnonymousFileSource.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\AnonymousFileSource.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\AnonymousFileSource.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\CharArrayOps.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\CharArrayOps.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\CharArrayOps.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\Dumper.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\Dumper.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\Dumper.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\IDumpable.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\IDumpable.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\IDumpable.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\PerThreadObject.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\PerThreadObject.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\PerThreadObject.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\StringHashtableOfInt.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\StringHashtableOfInt.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\StringHashtableOfInt.java,v
#
# -----------------
#
#
# failed with utf-8: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\StringMatcher.java,v
#
# failed with gbk: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\StringMatcher.java,v
#
# failed with gb18030: J:\EECS6444\Raw_Data\cvs\eclipse\org.eclipse.jdt.core\model\org\eclipse\jdt\internal\core\util\Attic\StringMatcher.java,v
#
# -----------------

# %%
#                 ## skip the non-java code: 
#                 if ".java,v" not in file:
#                         continue
#                 ## get the lines from original files. 
#                 lines = None
#                 with open(os.path.join(path, file), "r") as f: # , encoding="utf-8"
#                     lines = f.readlines()
#                 ## skip the non-java file
#                 ## this is the latest version of this file. 
#                 # print(re.split("\s", lines[0].replace(";", ""))[1])
#                 log_start = False
#                 full_code = []
#                 ##
#                 for l in lines:
#                     line = l.strip().lower()
#                     if log_start:
#                         full_code.append(line)
#                     ## log starts from here.
#                     if line == "text":
#                         log_start = True
#                     ## log ends here.
#                     if line == "@" and log_start == True:
#                         break
#                 code_content = "\n".join(full_code)[1:-1]
#                 ##
#                 file_name = root_PATH + os.path.join(path, file).replace(PATH, "").replace(",v", "").replace(os.sep, "#")
#                 with open(os.path.join(root_PATH, file_name), "w") as rf:
#                     rf.write(code_content)
