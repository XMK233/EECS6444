# %%
import os, re, shutil, javalang
import pandas as pd

def read_through_all_the_files_in_a_path(PATH):
    root_PATH = PATH.split("\\")[-1]
    ## java files will be stored into this folder.
    if not os.path.exists(root_PATH):
        os.makedirs(root_PATH)
    group = os.walk(PATH)
    for path, directory, filelist in group:
        for file in filelist:
            try:
                ## parse_file(PATH, root_PATH, path, file, "utf-8")
                if ".java" not in file:
                    continue
                new_file_name = os.path.join(path, file).replace(PATH, "").replace(",v", "").replace(os.sep, "#")[1:]
                shutil.copy(
                    os.path.join(path, file),
                    os.path.join(root_PATH, new_file_name)
                )
            except:
                print("failed with utf-8: {}\n".format(os.path.join(path, file)))
    return

def rename_java_files(root_PATH, new_root_PATH):
    """
    Rename the file as this format: package.name.java.
    Kim insist so. I don't know the meaning of naming like this.
    """
    if not os.path.exists(new_root_PATH):
        os.makedirs(new_root_PATH)
    # with open("{}_fileName_packageClassName.csv".format(root_PATH), "w") as fp:
    for code_file in os.listdir(root_PATH):
        try:
            with open(os.path.join(os.getcwd(), root_PATH, code_file), "r", encoding="utf-8") as cf:
                lines = cf.readlines()
            for line in lines:
                if "package " not in line:
                    continue
                match_rst = re.match("^package [\s\S]+;$", line)
                if match_rst == None:
                    continue
                ###
                package_name = match_rst.group().split()[1][0:-1]
                java_file_name = code_file.split("#")[-1]
                new_file_path = os.path.join(os.getcwd(), new_root_PATH, "{}.{}".format(package_name, java_file_name)  )
                # fp.write(
                #     "{},{}\n".format(
                #         code_file,
                #         os.path.join("{}.{}".format(package_name, java_file_name))
                #     )
                # )
                with open(new_file_path, "w") as ff:
                    ff.write("".join(lines))
                break
        except:
            print("failed: {}".format(code_file))
            
def map_from_metrics_side(root_PATH, new_root_PATH):
    """
    Generate a file: filename, packagename, filename 
    """
    with open("{}_metrics_file_map.csv".format(new_root_PATH), "w") as fp:
        fp.write("{},{},{}\n".format("file", "package", "java"))
        for code_file in os.listdir(root_PATH):
            try:
                with open(os.path.join(os.getcwd(), root_PATH, code_file), "r", encoding="utf-8") as cf:
                    lines = cf.readlines()
                for line in lines:
                    if "package " not in line:
                        continue
                    match_rst = re.match("^package [\s\S]+;$", line)
                    if match_rst == None:
                        continue
                    ###
                    package_name = match_rst.group().split()[1][0:-1]
                    java_file_name = code_file.split("#")[-1]
                    new_file_path = os.path.join(os.getcwd(), new_root_PATH, "{}.{}".format(package_name, java_file_name)  )
                    fp.write(
                        "{},{},{}\n".format(
                            code_file,
                            package_name,
                            java_file_name
                        )
                    )
                    # with open(new_file_path, "w") as ff:
                    #     ff.write("".join(lines))
                    break
            except:
                print("failed: {}".format(code_file))

def parse_java_files_file_level_interface_class(PATH, root_PATH):
    with open("{}_count_interface_class.csv".format(root_PATH), "w") as ff:  ## file for field
        ff.write("{},{},{},{},{}\n".format("file", "num_of_anony", "num_of_interface", "num_of_class", "line_of_code"))
        ## start to iterate the files:
        for file in os.listdir(PATH):
            if ".java" not in file:
                continue
            #####
            ## within each code file:
            #####
            try:
                with open(os.path.join(PATH, file), "r") as pf:
                    content = pf.readlines()
                    code_string = "".join(content)
                    tree = javalang.parse.parse(code_string)
                    #####
                    counter_of_anony = "??"
                    #####
                    counter_interface = 0
                    ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
                    for path, node in tree.filter(javalang.tree.InterfaceDeclaration):
                        counter_interface += 1
                    #####
                    counter_class = 0
                    ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
                    for path, node in tree.filter(javalang.tree.ClassDeclaration):
                        counter_class += 1
                    ff.write("{},{},{},{},{}\n".format(file.replace("#", "\\"), counter_of_anony, counter_interface, counter_class,
                                                       len(content)))
            except:
                print("failed:", file)


def parse_java_files_class_level_method(PATH, root_PATH):
    with open("{}_method.csv".format(root_PATH), "w") as ff:  ## file for field
        ff.write(
            "{},{},{},{},{},{},{}\n".format(
                "file",
                "NOM_num", "NOM_max", "NOM_total",
                "NSM_num", "NSM_max", "NSM_total"
            )
        )
        ## start to iterate the files:
        for file in os.listdir(PATH):
            if ".java" not in file:
                continue
            #####
            ## within each code file:
            #####
            try:
                with open(os.path.join(PATH, file), "r") as pf:
                    content = pf.readlines()
                code_string = "".join(content)
                tree = javalang.parse.parse(code_string)
                normal = {
                    "max": 0,
                    "avg": 0,
                    "num_of_class": 0,
                    "total": 0
                }
                static = {
                    "max": 0,
                    "avg": 0,
                    "num_of_class": 0,
                    "total": 0
                }
                ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
                for path, node in tree.filter(javalang.tree.ClassDeclaration):
                    #####
                    ## within each class:
                    #####
                    ## methods:
                    normal["num_of_class"] += 1
                    static["num_of_class"] += 1
                    counter_method = 0
                    counter_method_static = 0
                    for path1, node1 in node.filter(
                            javalang.tree.MethodDeclaration):  ## node1 is each line of MethodDeclaration
                        if "static" in node1.modifiers:
                            counter_method_static += 1
                        else:
                            counter_method += 1
                    normal["max"] = normal["max"] if counter_method <= normal["max"] else counter_method
                    static["max"] = static["max"] if counter_method_static <= static["max"] else counter_method_static
                    normal["total"] += counter_method
                    static["total"] += counter_method_static
#                 normal["avg"] = normal["total"] / normal["num_of_class"] if normal[
#                                                                                 "num_of_class"] > 0 else 1  ### IF THE normal["num_of_class"] IS 0, THEN WE WILL MANUALLY CHANGE IT TO 1
#                 static["avg"] = static["total"] / static["num_of_class"] if normal[
#                                                                                 "num_of_class"] > 0 else 1  ### IF THE normal["num_of_class"] IS 0, THEN WE WILL MANUALLY CHANGE IT TO 1
                ff.write(
                    "{},{},{},{},{},{},{}\n".format(
                        file.replace("#", "\\"),
                        normal["num_of_class"], normal["max"], normal["total"],
                        static["num_of_class"], static["max"], static["total"],
                    )
                )
            except:
                print("failed:", file)
                continue


def parse_java_files_class_level_field(PATH, root_PATH):
    with open("{}_field.csv".format(root_PATH), "w") as ff:  ## file for field
        ff.write(
            "{},{},{},{},{},{},{}\n".format(
                "file",
                "NOF_num", "NOF_max", "NOF_total",
                "NSF_num", "NSF_max", "NSF_total"
            )
        )
        ## start to iterate the files:
        for file in os.listdir(PATH):
            if ".java" not in file:
                continue
            #####
            ## within each code file:
            #####
            try:
                with open(os.path.join(PATH, file), "r") as pf:
                    content = pf.readlines()
                code_string = "".join(content)
                tree = javalang.parse.parse(code_string)
                normal = {
                    "max": 0,
                    "avg": 0,
                    "num_of_class": 0,
                    "total": 0
                }
                static = {
                    "max": 0,
                    "avg": 0,
                    "num_of_class": 0,
                    "total": 0
                }
                ## https://github.com/c2nes/javalang/blob/master/javalang/tree.py
                for path, node in tree.filter(javalang.tree.ClassDeclaration):
                    #####
                    ## within each class:
                    #####
                    # print(node.name)
                    ## fields:
                    normal["num_of_class"] += 1
                    static["num_of_class"] += 1
                    counter_field = 0
                    counter_field_static = 0
                    for path1, node1 in node.filter(
                            javalang.tree.FieldDeclaration):  ## node1 is each line of FieldDeclaration
                        if "static" in node1.modifiers:
                            for variable_declarator in node1.declarators:  ## basically one declarator is just one line. Within 1 line, there can be several varaibles.
                                # print("static: ", node1.modifiers, variable_declarator.name)
                                counter_field_static += 1
                        else:
                            for variable_declarator in node1.declarators:  ## basically one declarator is just one line. Within 1 line, there can be several varaibles.
                                # print("not: ", node1.modifiers, variable_declarator.name)
                                counter_field += 1
                    normal["max"] = normal["max"] if counter_field <= normal["max"] else counter_field
                    static["max"] = static["max"] if counter_field_static <= static["max"] else counter_field_static
                    normal["total"] += counter_field
                    static["total"] += counter_field_static
#                 normal["avg"] = normal["total"] / normal["num_of_class"] if normal[
#                                                                                 "num_of_class"] > 0 else 1  ### IF THE normal["num_of_class"] IS 0, THEN WE WILL MANUALLY CHANGE IT TO 1
#                 static["avg"] = static["total"] / static["num_of_class"] if normal[
#                                                                                 "num_of_class"] > 0 else 1  ### IF THE normal["num_of_class"] IS 0, THEN WE WILL MANUALLY CHANGE IT TO 1
                ff.write(
                    "{},{},{},{},{},{},{}\n".format(
                        file.replace("#", "\\"),
                        normal["num_of_class"], normal["max"], normal["total"],
                        static["num_of_class"], static["max"], static["total"],
                    )
                )
            except:
                print("failed:", file)

read_through_all_the_files_in_a_path(r"J:\EECS6444\Raw_Data\eclipse-sourceBuild-srcIncluded-2.1.1")
# # -----------------------------
map_from_metrics_side("eclipse-sourceBuild-srcIncluded-2.1.1", "plugin")
parse_java_files_class_level_field("eclipse-sourceBuild-srcIncluded-2.1.1", "plugin")
print("field finished")
parse_java_files_class_level_method("eclipse-sourceBuild-srcIncluded-2.1.1", "plugin")
print("method finished")
parse_java_files_file_level_interface_class("eclipse-sourceBuild-srcIncluded-2.1.1", "plugin")
print("file level finished")
# ----------------
# rename_java_files("eclipse-sourceBuild-srcIncluded-3.0.1", "eclipse_3.0.1")
# parse_java_files_class_level_field("eclipse_3.0.1", "eclipse")
# print("field finished")
# parse_java_files_class_level_method("eclipse_3.0.1", "eclipse")
# print("method finished")
# parse_java_files_file_level_interface_class("eclipse_3.0.1", "eclipse")
# print("file level finished")
# Out:
# failed: plugins#org.eclipse.jdt.debug#model#org#eclipse#jdt#internal#debug#core#StringMatcher.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#console#StringMatcher.java
# failed: plugins#org.eclipse.jdt.ui#ui#org#eclipse#jdt#internal#ui#util#StringMatcher.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#util#StringMatcher.java
# failed: plugins#org.eclipse.search#search#org#eclipse#search#internal#ui#util#StringMatcher.java
# failed: plugins#org.eclipse.ui.externaltools#External Tools Base#org#eclipse#ui#externaltools#internal#model#StringMatcher.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#navigator#StringMatcher.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#misc#StringMatcher.java
# failed: plugins#org.apache.lucene#src#org#apache#lucene#demo#html#HTMLParser.java
# failed: plugins#org.eclipse.ant.core#src_ant#org#eclipse#ant#internal#core#ant#InternalAntRunner.java
# failed: plugins#org.eclipse.ant.core#src_ant#org#eclipse#ant#internal#core#ant#InternalProject.java
# failed: plugins#org.eclipse.core.boot#src#org#eclipse#core#internal#boot#BundleStats.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#resources#SaveManager.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#resources#XMLWriter.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#utils#Queue.java
# failed: plugins#org.eclipse.core.runtime#src#org#eclipse#core#internal#runtime#AdapterManager.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#AbstractDebugActionDelegate.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#EnableBreakpointsAction.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#OpenBreakpointMarkerAction.java
# failed: plugins#org.eclipse.help#src#org#eclipse#help#internal#toc#DirectoryToc.java
# failed: plugins#org.eclipse.jdt.core#compiler#org#eclipse#jdt#internal#compiler#CompilationResult.java
# failed: plugins#org.eclipse.jdt.core#compiler#org#eclipse#jdt#internal#compiler#lookup#SourceTypeBinding.java
# failed: plugins#org.eclipse.jdt.core#model#org#eclipse#jdt#internal#core#CopyResourceElementsOperation.java
# failed: plugins#org.eclipse.jdt.debug#jdi#org#eclipse#jdi#internal#request#EventRequestManagerImpl.java
# failed: plugins#org.eclipse.jdt.debug#model#org#eclipse#jdt#internal#debug#core#StringMatcher.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#AbstractAddStepFilterAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#BreakpointHitCountAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#BreakpointToggleAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#DropToFrameAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#ExcludeExceptionLocationAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#OpenTypeAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#console#StringMatcher.java
# failed: plugins#org.eclipse.jdt.ui#ui refactoring#org#eclipse#jdt#internal#ui#refactoring#nls#search#NLSSearchResultCollector.java
# failed: plugins#org.eclipse.jdt.ui#ui#org#eclipse#jdt#internal#ui#jarpackager#JarPackageWizardPage.java
# failed: plugins#org.eclipse.jdt.ui#ui#org#eclipse#jdt#internal#ui#util#StringMatcher.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#action#SubContributionManager.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#dialogs#ErrorDialog.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#preference#PreferenceStore.java
# failed: plugins#org.eclipse.pde#src#org#eclipse#pde#internal#builders#ManifestConsistencyChecker.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#plugin#PluginElement.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#ChoiceRestriction.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#Schema.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#SchemaRegistry.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#SourceAttachmentManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#TempFileManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#TracingOptionsManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#util#StringMatcher.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#WorkspaceModelManager.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#editor#PDEMultiPageEditor.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#editor#schema#EnumerationRestrictionPage.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#launcher#TracingLauncherTab.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#launcher#TracingPropertySource.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#util#SharedLabelProvider.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#wizards#RequiredPluginsContainerPage.java
# failed: plugins#org.eclipse.pde.ui#templates#view#java#$className$.java
# failed: plugins#org.eclipse.search#search#org#eclipse#search#internal#ui#util#StringMatcher.java
# failed: plugins#org.eclipse.swt#Eclipse SWT Drag and Drop#win32#org#eclipse#swt#dnd#Clipboard.java
# failed: plugins#org.eclipse.swt#Eclipse SWT Drag and Drop#win32#org#eclipse#swt#dnd#DropTarget.java
# failed: plugins#org.eclipse.swt#Eclipse SWT#common#org#eclipse#swt#layout#GridLayout.java
# failed: plugins#org.eclipse.team.cvs.ui#src#org#eclipse#team#internal#ccvs#ui#XMLWriter.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Editor#org#eclipse#ui#externaltools#internal#ant#dtd#schema#Attribute.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Editor#org#eclipse#ui#externaltools#internal#ant#dtd#schema#SchemaFactory.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Tools Support#org#eclipse#ui#externaltools#internal#ant#preferences#AntClasspathBlock.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Tools Support#org#eclipse#ui#externaltools#internal#ant#preferences#AntPage.java
# failed: plugins#org.eclipse.ui.externaltools#External Tools Base#org#eclipse#ui#externaltools#internal#model#StringMatcher.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#navigator#NavigatorDragAdapter.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#navigator#StringMatcher.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#properties#PropertySheetViewer.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#actions#AddBookmarkAction.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#actions#OpenSystemEditorAction.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardExportPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardExportResourcesPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardNewFileCreationPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardNewFolderMainPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#DetachedWindow.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#ActionSetSelectionDialog.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#NewProjectWizard.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#ProjectCapabilityEditingPropertyPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#UpdateProjectCapabilityWizard.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#EditorManager.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#EditorWorkbook.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#misc#ProjectCapabilitySelectionGroup.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#misc#StringMatcher.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#ObjectContributorManager.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#PartTabFolder.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#Perspective.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#PerspectivePresentation.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#ActionSetRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#CapabilityRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#EditorRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#PerspectiveRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#ViewRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchPlugin.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchWindow.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#CellEditorActionHandler.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#MultiPageEditor.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#PageBookView.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#wizards#datatransfer#WizardFileSystemResourceImportPage1.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#wizards#newresource#BasicNewResourceWizard.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#forms#DetailsForm.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#model#BookmarkUtil.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#parts#SharedLabelProvider.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#views#SearchMonitorManager.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#wizards#DuplicateConflictsDialog.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#wizards#MultiTargetPage.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#client#AbstractResourceHandle.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#client#URLTable.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#http#client#HttpClient.java
# failed: plugins#org.eclipse.webdav#src#interface#org#eclipse#webdav#dom#ElementEditor.java
# failed: plugins#org.eclipse.webdav#src#kernel#org#eclipse#webdav#internal#kernel#utils#ExcludingEnumeration.java
# field finished
# failed: plugins#org.apache.lucene#src#org#apache#lucene#demo#html#HTMLParser.java
# failed: plugins#org.eclipse.ant.core#src_ant#org#eclipse#ant#internal#core#ant#InternalAntRunner.java
# failed: plugins#org.eclipse.ant.core#src_ant#org#eclipse#ant#internal#core#ant#InternalProject.java
# failed: plugins#org.eclipse.core.boot#src#org#eclipse#core#internal#boot#BundleStats.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#resources#SaveManager.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#resources#XMLWriter.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#utils#Queue.java
# failed: plugins#org.eclipse.core.runtime#src#org#eclipse#core#internal#runtime#AdapterManager.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#AbstractDebugActionDelegate.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#EnableBreakpointsAction.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#OpenBreakpointMarkerAction.java
# failed: plugins#org.eclipse.help#src#org#eclipse#help#internal#toc#DirectoryToc.java
# failed: plugins#org.eclipse.jdt.core#compiler#org#eclipse#jdt#internal#compiler#CompilationResult.java
# failed: plugins#org.eclipse.jdt.core#compiler#org#eclipse#jdt#internal#compiler#lookup#SourceTypeBinding.java
# failed: plugins#org.eclipse.jdt.core#model#org#eclipse#jdt#internal#core#CopyResourceElementsOperation.java
# failed: plugins#org.eclipse.jdt.debug#jdi#org#eclipse#jdi#internal#request#EventRequestManagerImpl.java
# failed: plugins#org.eclipse.jdt.debug#model#org#eclipse#jdt#internal#debug#core#StringMatcher.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#AbstractAddStepFilterAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#BreakpointHitCountAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#BreakpointToggleAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#DropToFrameAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#ExcludeExceptionLocationAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#OpenTypeAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#console#StringMatcher.java
# failed: plugins#org.eclipse.jdt.ui#ui refactoring#org#eclipse#jdt#internal#ui#refactoring#nls#search#NLSSearchResultCollector.java
# failed: plugins#org.eclipse.jdt.ui#ui#org#eclipse#jdt#internal#ui#jarpackager#JarPackageWizardPage.java
# failed: plugins#org.eclipse.jdt.ui#ui#org#eclipse#jdt#internal#ui#util#StringMatcher.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#action#SubContributionManager.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#dialogs#ErrorDialog.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#preference#PreferenceStore.java
# failed: plugins#org.eclipse.pde#src#org#eclipse#pde#internal#builders#ManifestConsistencyChecker.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#plugin#PluginElement.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#ChoiceRestriction.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#Schema.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#SchemaRegistry.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#SourceAttachmentManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#TempFileManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#TracingOptionsManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#util#StringMatcher.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#WorkspaceModelManager.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#editor#PDEMultiPageEditor.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#editor#schema#EnumerationRestrictionPage.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#launcher#TracingLauncherTab.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#launcher#TracingPropertySource.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#util#SharedLabelProvider.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#wizards#RequiredPluginsContainerPage.java
# failed: plugins#org.eclipse.pde.ui#templates#view#java#$className$.java
# failed: plugins#org.eclipse.search#search#org#eclipse#search#internal#ui#util#StringMatcher.java
# failed: plugins#org.eclipse.swt#Eclipse SWT Drag and Drop#win32#org#eclipse#swt#dnd#Clipboard.java
# failed: plugins#org.eclipse.swt#Eclipse SWT Drag and Drop#win32#org#eclipse#swt#dnd#DropTarget.java
# failed: plugins#org.eclipse.swt#Eclipse SWT#common#org#eclipse#swt#layout#GridLayout.java
# failed: plugins#org.eclipse.team.cvs.ui#src#org#eclipse#team#internal#ccvs#ui#XMLWriter.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Editor#org#eclipse#ui#externaltools#internal#ant#dtd#schema#Attribute.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Editor#org#eclipse#ui#externaltools#internal#ant#dtd#schema#SchemaFactory.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Tools Support#org#eclipse#ui#externaltools#internal#ant#preferences#AntClasspathBlock.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Tools Support#org#eclipse#ui#externaltools#internal#ant#preferences#AntPage.java
# failed: plugins#org.eclipse.ui.externaltools#External Tools Base#org#eclipse#ui#externaltools#internal#model#StringMatcher.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#navigator#NavigatorDragAdapter.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#navigator#StringMatcher.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#properties#PropertySheetViewer.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#actions#AddBookmarkAction.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#actions#OpenSystemEditorAction.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardExportPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardExportResourcesPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardNewFileCreationPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardNewFolderMainPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#DetachedWindow.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#ActionSetSelectionDialog.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#NewProjectWizard.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#ProjectCapabilityEditingPropertyPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#UpdateProjectCapabilityWizard.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#EditorManager.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#EditorWorkbook.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#misc#ProjectCapabilitySelectionGroup.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#misc#StringMatcher.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#ObjectContributorManager.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#PartTabFolder.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#Perspective.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#PerspectivePresentation.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#ActionSetRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#CapabilityRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#EditorRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#PerspectiveRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#ViewRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchPlugin.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchWindow.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#CellEditorActionHandler.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#MultiPageEditor.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#PageBookView.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#wizards#datatransfer#WizardFileSystemResourceImportPage1.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#wizards#newresource#BasicNewResourceWizard.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#forms#DetailsForm.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#model#BookmarkUtil.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#parts#SharedLabelProvider.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#views#SearchMonitorManager.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#wizards#DuplicateConflictsDialog.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#wizards#MultiTargetPage.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#client#AbstractResourceHandle.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#client#URLTable.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#http#client#HttpClient.java
# failed: plugins#org.eclipse.webdav#src#interface#org#eclipse#webdav#dom#ElementEditor.java
# failed: plugins#org.eclipse.webdav#src#kernel#org#eclipse#webdav#internal#kernel#utils#ExcludingEnumeration.java
# method finished
# failed: plugins#org.apache.lucene#src#org#apache#lucene#demo#html#HTMLParser.java
# failed: plugins#org.eclipse.ant.core#src_ant#org#eclipse#ant#internal#core#ant#InternalAntRunner.java
# failed: plugins#org.eclipse.ant.core#src_ant#org#eclipse#ant#internal#core#ant#InternalProject.java
# failed: plugins#org.eclipse.core.boot#src#org#eclipse#core#internal#boot#BundleStats.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#resources#SaveManager.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#resources#XMLWriter.java
# failed: plugins#org.eclipse.core.resources#src#org#eclipse#core#internal#utils#Queue.java
# failed: plugins#org.eclipse.core.runtime#src#org#eclipse#core#internal#runtime#AdapterManager.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#AbstractDebugActionDelegate.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#EnableBreakpointsAction.java
# failed: plugins#org.eclipse.debug.ui#ui#org#eclipse#debug#internal#ui#actions#OpenBreakpointMarkerAction.java
# failed: plugins#org.eclipse.help#src#org#eclipse#help#internal#toc#DirectoryToc.java
# failed: plugins#org.eclipse.jdt.core#compiler#org#eclipse#jdt#internal#compiler#CompilationResult.java
# failed: plugins#org.eclipse.jdt.core#compiler#org#eclipse#jdt#internal#compiler#lookup#SourceTypeBinding.java
# failed: plugins#org.eclipse.jdt.core#model#org#eclipse#jdt#internal#core#CopyResourceElementsOperation.java
# failed: plugins#org.eclipse.jdt.debug#jdi#org#eclipse#jdi#internal#request#EventRequestManagerImpl.java
# failed: plugins#org.eclipse.jdt.debug#model#org#eclipse#jdt#internal#debug#core#StringMatcher.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#AbstractAddStepFilterAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#BreakpointHitCountAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#BreakpointToggleAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#DropToFrameAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#ExcludeExceptionLocationAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#actions#OpenTypeAction.java
# failed: plugins#org.eclipse.jdt.debug.ui#ui#org#eclipse#jdt#internal#debug#ui#console#StringMatcher.java
# failed: plugins#org.eclipse.jdt.ui#ui refactoring#org#eclipse#jdt#internal#ui#refactoring#nls#search#NLSSearchResultCollector.java
# failed: plugins#org.eclipse.jdt.ui#ui#org#eclipse#jdt#internal#ui#jarpackager#JarPackageWizardPage.java
# failed: plugins#org.eclipse.jdt.ui#ui#org#eclipse#jdt#internal#ui#util#StringMatcher.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#action#SubContributionManager.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#dialogs#ErrorDialog.java
# failed: plugins#org.eclipse.jface#src#org#eclipse#jface#preference#PreferenceStore.java
# failed: plugins#org.eclipse.pde#src#org#eclipse#pde#internal#builders#ManifestConsistencyChecker.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#plugin#PluginElement.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#ChoiceRestriction.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#Schema.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#schema#SchemaRegistry.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#SourceAttachmentManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#TempFileManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#TracingOptionsManager.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#util#StringMatcher.java
# failed: plugins#org.eclipse.pde.core#src#org#eclipse#pde#internal#core#WorkspaceModelManager.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#editor#PDEMultiPageEditor.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#editor#schema#EnumerationRestrictionPage.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#launcher#TracingLauncherTab.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#launcher#TracingPropertySource.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#util#SharedLabelProvider.java
# failed: plugins#org.eclipse.pde.ui#src#org#eclipse#pde#internal#ui#wizards#RequiredPluginsContainerPage.java
# failed: plugins#org.eclipse.pde.ui#templates#view#java#$className$.java
# failed: plugins#org.eclipse.search#search#org#eclipse#search#internal#ui#util#StringMatcher.java
# failed: plugins#org.eclipse.swt#Eclipse SWT Drag and Drop#win32#org#eclipse#swt#dnd#Clipboard.java
# failed: plugins#org.eclipse.swt#Eclipse SWT Drag and Drop#win32#org#eclipse#swt#dnd#DropTarget.java
# failed: plugins#org.eclipse.swt#Eclipse SWT#common#org#eclipse#swt#layout#GridLayout.java
# failed: plugins#org.eclipse.team.cvs.ui#src#org#eclipse#team#internal#ccvs#ui#XMLWriter.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Editor#org#eclipse#ui#externaltools#internal#ant#dtd#schema#Attribute.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Editor#org#eclipse#ui#externaltools#internal#ant#dtd#schema#SchemaFactory.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Tools Support#org#eclipse#ui#externaltools#internal#ant#preferences#AntClasspathBlock.java
# failed: plugins#org.eclipse.ui.externaltools#Ant Tools Support#org#eclipse#ui#externaltools#internal#ant#preferences#AntPage.java
# failed: plugins#org.eclipse.ui.externaltools#External Tools Base#org#eclipse#ui#externaltools#internal#model#StringMatcher.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#navigator#NavigatorDragAdapter.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#navigator#StringMatcher.java
# failed: plugins#org.eclipse.ui.views#src#org#eclipse#ui#views#properties#PropertySheetViewer.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#actions#AddBookmarkAction.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#actions#OpenSystemEditorAction.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardExportPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardExportResourcesPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardNewFileCreationPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#dialogs#WizardNewFolderMainPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#DetachedWindow.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#ActionSetSelectionDialog.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#NewProjectWizard.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#ProjectCapabilityEditingPropertyPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#dialogs#UpdateProjectCapabilityWizard.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#EditorManager.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#EditorWorkbook.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#misc#ProjectCapabilitySelectionGroup.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#misc#StringMatcher.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#ObjectContributorManager.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#PartTabFolder.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#Perspective.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#PerspectivePresentation.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#ActionSetRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#CapabilityRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#EditorRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#PerspectiveRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#registry#ViewRegistry.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchPage.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchPlugin.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#internal#WorkbenchWindow.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#CellEditorActionHandler.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#MultiPageEditor.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#part#PageBookView.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#wizards#datatransfer#WizardFileSystemResourceImportPage1.java
# failed: plugins#org.eclipse.ui.workbench#Eclipse UI#org#eclipse#ui#wizards#newresource#BasicNewResourceWizard.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#forms#DetailsForm.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#model#BookmarkUtil.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#parts#SharedLabelProvider.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#views#SearchMonitorManager.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#wizards#DuplicateConflictsDialog.java
# failed: plugins#org.eclipse.update.ui#src#org#eclipse#update#internal#ui#wizards#MultiTargetPage.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#client#AbstractResourceHandle.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#client#URLTable.java
# failed: plugins#org.eclipse.webdav#src#client#org#eclipse#webdav#http#client#HttpClient.java
# failed: plugins#org.eclipse.webdav#src#interface#org#eclipse#webdav#dom#ElementEditor.java
# failed: plugins#org.eclipse.webdav#src#kernel#org#eclipse#webdav#internal#kernel#utils#ExcludingEnumeration.java
# file level finished
